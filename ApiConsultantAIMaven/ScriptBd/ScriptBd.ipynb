-- %%
/*    ==ScriptingParameters==

    SourceDatabaseEngineEdition : Edición de Microsoft Azure SQL Database
    SourceDatabaseEngineType : Microsoft Azure SQL Database

    TargetDatabaseEngineEdition : Edición de Microsoft Azure SQL Database
    TargetDatabaseEngineType : Microsoft Azure SQL Database
*/

-- %% [markdown]
-- # [dbo].[FineTunesList]

-- %%
/****** Object:  UserDefinedTableType [dbo].[FineTunesList]    Script Date: 19/08/2023 4:24:06 p. m. ******/
CREATE TYPE [dbo].[FineTunesList] AS TABLE(
	[Prompt] [varchar](2000) NOT NULL,
	[Completion] [varchar](2000) NOT NULL
)
GO

-- %% [markdown]
-- # [dbo].[Area]

-- %%
/****** Object:  Table [dbo].[Area]    Script Date: 19/08/2023 4:24:06 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
SET ANSI_PADDING ON
GO
CREATE TABLE [dbo].[Area](
	[idArea] [int] IDENTITY(1,1) NOT NULL,
	[idEmpresa] [int] NOT NULL,
	[nombre] [varchar](50) NOT NULL,
	[descripcion] [varchar](50) NULL,
	[reprecentante] [varchar](50) NULL,
	[idUsuarioCreacion] [int] NOT NULL,
	[fechaCreacion] [datetime] NOT NULL,
	[idUsuarioModificacion] [int] NOT NULL,
	[fechaModificacion] [datetime] NOT NULL,
	[idEstado] [int] NULL,
 CONSTRAINT [PK_Area] PRIMARY KEY CLUSTERED 
(
	[idArea] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
SET ANSI_PADDING OFF
GO
ALTER AUTHORIZATION ON [dbo].[Area] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[Ciudades]

-- %%
/****** Object:  Table [dbo].[Ciudades]    Script Date: 19/08/2023 4:24:06 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
SET ANSI_PADDING ON
GO
CREATE TABLE [dbo].[Ciudades](
	[idciudad] [int] NOT NULL,
	[codigoDane] [varchar](15) NULL,
	[ciudad] [varchar](40) NOT NULL,
	[departamento] [varchar](40) NOT NULL,
	[estado] [int] NOT NULL,
 CONSTRAINT [PK_ciudades] PRIMARY KEY CLUSTERED 
(
	[idciudad] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
SET ANSI_PADDING OFF
GO
ALTER AUTHORIZATION ON [dbo].[Ciudades] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[ConfigValues]

-- %%
/****** Object:  Table [dbo].[ConfigValues]    Script Date: 19/08/2023 4:24:06 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
SET ANSI_PADDING ON
GO
CREATE TABLE [dbo].[ConfigValues](
	[idConfig] [numeric](18, 0) IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](50) NOT NULL,
	[valor] [varchar](450) NULL,
	[idEstado] [int] NULL,
 CONSTRAINT [PK_ConfigValues] PRIMARY KEY CLUSTERED 
(
	[idConfig] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
SET ANSI_PADDING OFF
GO
ALTER AUTHORIZATION ON [dbo].[ConfigValues] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[Conversation]

-- %%
/****** Object:  Table [dbo].[Conversation]    Script Date: 19/08/2023 4:24:06 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
SET ANSI_PADDING ON
GO
CREATE TABLE [dbo].[Conversation](
	[idConversation] [int] IDENTITY(1,1) NOT NULL,
	[idCustomer] [int] NOT NULL,
	[Ask] [varchar](max) NOT NULL,
	[Answer] [varchar](max) NULL,
	[Reaction] [bit] NULL,
	[Message] [varchar](200) NULL,
	[idUserCreation] [int] NOT NULL,
	[DateCreation] [datetime] NOT NULL,
	[idUserModification] [int] NOT NULL,
	[DateModification] [datetime] NOT NULL,
 CONSTRAINT [PK_Conversation] PRIMARY KEY CLUSTERED 
(
	[idConversation] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO
SET ANSI_PADDING OFF
GO
ALTER AUTHORIZATION ON [dbo].[Conversation] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[Customer]

-- %%
/****** Object:  Table [dbo].[Customer]    Script Date: 19/08/2023 4:24:06 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
SET ANSI_PADDING ON
GO
CREATE TABLE [dbo].[Customer](
	[IdCustomer] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](150) NULL,
	[PhotoProfile] [varchar](max) NULL,
	[Email] [varchar](100) NOT NULL,
	[CountryLocation] [varchar](200) NULL,
	[UserId] [varchar](50) NULL,
	[IdUserCreation] [int] NOT NULL,
	[DateCreation] [datetime] NOT NULL,
	[IdUserModification] [int] NOT NULL,
	[DateModification] [datetime] NOT NULL,
 CONSTRAINT [PK_Customer] PRIMARY KEY CLUSTERED 
(
	[IdCustomer] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO
SET ANSI_PADDING OFF
GO
ALTER AUTHORIZATION ON [dbo].[Customer] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[Empresa]

-- %%
/****** Object:  Table [dbo].[Empresa]    Script Date: 19/08/2023 4:24:06 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
SET ANSI_PADDING ON
GO
CREATE TABLE [dbo].[Empresa](
	[idEmpresa] [int] IDENTITY(1,1) NOT NULL,
	[nit] [varchar](20) NOT NULL,
	[nombre] [varchar](50) NOT NULL,
	[direccion] [varchar](50) NULL,
	[telefono] [varchar](15) NULL,
	[reprecentante] [varchar](50) NULL,
	[idUsuarioCreacion] [int] NOT NULL,
	[fechaCreacion] [datetime] NOT NULL,
	[idUsuarioModificacion] [int] NOT NULL,
	[fechaModificacion] [datetime] NOT NULL,
 CONSTRAINT [PK_Empresa] PRIMARY KEY CLUSTERED 
(
	[idEmpresa] DESC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
SET ANSI_PADDING OFF
GO
ALTER AUTHORIZATION ON [dbo].[Empresa] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[HistorialPwdUsuario]

-- %%
/****** Object:  Table [dbo].[HistorialPwdUsuario]    Script Date: 19/08/2023 4:24:06 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
SET ANSI_PADDING ON
GO
CREATE TABLE [dbo].[HistorialPwdUsuario](
	[idHistorialPwdUsuario] [int] IDENTITY(1,1) NOT NULL,
	[idUsuario] [int] NOT NULL,
	[pwd] [varchar](100) NOT NULL,
	[fechaModificacion] [datetime] NOT NULL,
	[idModificador] [int] NOT NULL,
	[IngresoPrimeraVez] [bit] NOT NULL,
 CONSTRAINT [PK_HistorialPwdUsuario] PRIMARY KEY CLUSTERED 
(
	[idHistorialPwdUsuario] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
SET ANSI_PADDING OFF
GO
ALTER AUTHORIZATION ON [dbo].[HistorialPwdUsuario] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[LogIngresoAlSistema]

-- %%
/****** Object:  Table [dbo].[LogIngresoAlSistema]    Script Date: 19/08/2023 4:24:06 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LogIngresoAlSistema](
	[idLog] [numeric](18, 0) IDENTITY(1,1) NOT NULL,
	[idUsuario] [int] NOT NULL,
	[fechaIngreso] [datetime] NOT NULL,
 CONSTRAINT [PK_LogIngresoAlSistema] PRIMARY KEY CLUSTERED 
(
	[idLog] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
ALTER AUTHORIZATION ON [dbo].[LogIngresoAlSistema] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[LogServicios]

-- %%
/****** Object:  Table [dbo].[LogServicios]    Script Date: 19/08/2023 4:24:06 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
SET ANSI_PADDING ON
GO
CREATE TABLE [dbo].[LogServicios](
	[IdLogServicios] [numeric](18, 0) IDENTITY(1,1) NOT NULL,
	[Servicio] [varchar](1000) NULL,
	[Peticion] [varchar](max) NULL,
	[Respuesta] [varchar](max) NULL,
	[FechaRegistro] [datetime] NOT NULL,
 CONSTRAINT [PK_LogIntegracionClaro] PRIMARY KEY CLUSTERED 
(
	[IdLogServicios] DESC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO
SET ANSI_PADDING OFF
GO
ALTER AUTHORIZATION ON [dbo].[LogServicios] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[LogTrainingInformation]

-- %%
/****** Object:  Table [dbo].[LogTrainingInformation]    Script Date: 19/08/2023 4:24:06 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
SET ANSI_PADDING ON
GO
CREATE TABLE [dbo].[LogTrainingInformation](
	[IdLog] [int] IDENTITY(1,1) NOT NULL,
	[Id] [int] NOT NULL,
	[Prompt] [varchar](2000) NULL,
	[Completion] [varchar](2000) NULL,
	[IdUsuario] [int] NULL,
	[FechaRegistro] [datetime] NULL,
	[IdUsuarioLog] [int] NULL,
	[FechaLog] [datetime] NULL,
 CONSTRAINT [PK_LogTrainingInformation] PRIMARY KEY CLUSTERED 
(
	[IdLog] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
SET ANSI_PADDING OFF
GO
ALTER AUTHORIZATION ON [dbo].[LogTrainingInformation] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[LogTrainings]

-- %%
/****** Object:  Table [dbo].[LogTrainings]    Script Date: 19/08/2023 4:24:06 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
SET ANSI_PADDING ON
GO
CREATE TABLE [dbo].[LogTrainings](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[TrainingId] [varchar](250) NULL,
	[TrainingDate] [datetime] NULL
) ON [PRIMARY]
GO
SET ANSI_PADDING OFF
GO
UPDATE STATISTICS [dbo].[LogTrainings] WITH ROWCOUNT = 1, PAGECOUNT = 1
GO
ALTER AUTHORIZATION ON [dbo].[LogTrainings] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[Perfil]

-- %%
/****** Object:  Table [dbo].[Perfil]    Script Date: 19/08/2023 4:24:06 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
SET ANSI_PADDING ON
GO
CREATE TABLE [dbo].[Perfil](
	[idPerfil] [int] IDENTITY(1,1) NOT NULL,
	[idEmpresa] [int] NOT NULL,
	[perfil] [varchar](50) NOT NULL,
	[descripcion] [varchar](150) NULL,
	[idEstado] [int] NOT NULL,
	[fecha] [smalldatetime] NOT NULL,
	[idUsuarioCreacion] [int] NOT NULL,
	[fechaCreacion] [datetime] NOT NULL,
	[idUsuarioModificacion] [int] NOT NULL,
	[fechaModificacion] [datetime] NOT NULL,
 CONSTRAINT [PK_perfiles] PRIMARY KEY CLUSTERED 
(
	[idPerfil] DESC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
SET ANSI_PADDING OFF
GO
ALTER AUTHORIZATION ON [dbo].[Perfil] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[TrainingInformation]

-- %%
/****** Object:  Table [dbo].[TrainingInformation]    Script Date: 19/08/2023 4:24:06 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
SET ANSI_PADDING ON
GO
CREATE TABLE [dbo].[TrainingInformation](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Prompt] [varchar](2000) NULL,
	[Completion] [varchar](2000) NULL,
	[IdUsuario] [int] NULL,
	[FechaRegistro] [datetime] NULL,
 CONSTRAINT [PK_TrainingInformation] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
SET ANSI_PADDING OFF
GO
ALTER AUTHORIZATION ON [dbo].[TrainingInformation] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[TransitoriaCreacionUsuarios]

-- %%
/****** Object:  Table [dbo].[TransitoriaCreacionUsuarios]    Script Date: 19/08/2023 4:24:06 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
SET ANSI_PADDING ON
GO
CREATE TABLE [dbo].[TransitoriaCreacionUsuarios](
	[Identificacion] [varchar](250) NULL,
	[Nombre] [varchar](250) NULL,
	[Usuario] [varchar](250) NULL,
	[Telefono] [varchar](250) NULL,
	[Ciudad] [varchar](250) NULL,
	[Email] [varchar](250) NULL,
	[Perfil] [varchar](250) NULL,
	[Empresa] [varchar](250) NULL,
	[IdUsuario] [int] NULL
) ON [PRIMARY]
GO
SET ANSI_PADDING OFF
GO
UPDATE STATISTICS [dbo].[TransitoriaCreacionUsuarios] WITH ROWCOUNT = 0, PAGECOUNT = 0
GO
ALTER AUTHORIZATION ON [dbo].[TransitoriaCreacionUsuarios] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[UsuarioSistema]

-- %%
/****** Object:  Table [dbo].[UsuarioSistema]    Script Date: 19/08/2023 4:24:06 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
SET ANSI_PADDING ON
GO
CREATE TABLE [dbo].[UsuarioSistema](
	[idUsuario] [int] IDENTITY(1,1) NOT NULL,
	[numeroIdentificacion] [varchar](20) NOT NULL,
	[nombreApellido] [varchar](100) NOT NULL,
	[telefonos] [varchar](30) NULL,
	[email] [varchar](100) NULL,
	[idCiudad] [int] NOT NULL,
	[usuario] [varchar](50) NOT NULL,
	[pwd] [varchar](100) NOT NULL,
	[idEstado] [int] NOT NULL,
	[bloqueado] [bit] NOT NULL,
	[fechaCreacion] [datetime] NOT NULL,
	[idEmpresa] [int] NOT NULL,
	[idArea] [int] NULL,
	[token] [varchar](150) NULL,
	[fechaExpiracionToken] [datetime] NULL,
	[idUsuarioCreacion] [int] NOT NULL,
	[idusuarioModifica] [int] NOT NULL,
	[fechaModificacion] [datetime] NOT NULL,
	[fechaultimoIngreso] [datetime] NULL,
	[fechaCambioClave] [datetime] NULL,
	[idPerfil] [int] NOT NULL,
 CONSTRAINT [PK_UsuarioSistema] PRIMARY KEY CLUSTERED 
(
	[idUsuario] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
SET ANSI_PADDING OFF
GO
ALTER AUTHORIZATION ON [dbo].[UsuarioSistema] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[Area]

-- %%
SET IDENTITY_INSERT [dbo].[Area] ON 
INSERT [dbo].[Area] ([idArea], [idEmpresa], [nombre], [descripcion], [reprecentante], [idUsuarioCreacion], [fechaCreacion], [idUsuarioModificacion], [fechaModificacion], [idEstado]) VALUES (1, 1, N'IT', N'Area de tecnologia', N'NA', 1, CAST(N'2022-05-26T08:51:59.970' AS DateTime), 1, CAST(N'2022-05-26T08:51:59.970' AS DateTime), 1)
SET IDENTITY_INSERT [dbo].[Area] OFF
GO

-- %% [markdown]
-- # [dbo].[ConfigValues]

-- %%
SET IDENTITY_INSERT [dbo].[ConfigValues] ON 
INSERT [dbo].[ConfigValues] ([idConfig], [nombre], [valor], [idEstado]) VALUES (CAST(1 AS Numeric(18, 0)), N'ApikeyChatGPT', N'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', 1)
SET IDENTITY_INSERT [dbo].[ConfigValues] OFF
GO

-- %% [markdown]
-- # [dbo].[Empresa]

-- %%
SET IDENTITY_INSERT [dbo].[Empresa] ON 
INSERT [dbo].[Empresa] ([idEmpresa], [nit], [nombre], [direccion], [telefono], [reprecentante], [idUsuarioCreacion], [fechaCreacion], [idUsuarioModificacion], [fechaModificacion]) VALUES (1, N'800800800', N'METNET', N'xxxxx', N'zzzzz', N'Movistar', 1, CAST(N'2022-09-12T18:42:54.907' AS DateTime), 1, CAST(N'2022-09-12T18:42:54.907' AS DateTime))
SET IDENTITY_INSERT [dbo].[Empresa] OFF
GO

-- %% [markdown]
-- # [dbo].[LogIngresoAlSistema]

-- %%
SET IDENTITY_INSERT [dbo].[LogIngresoAlSistema] ON 
INSERT [dbo].[LogIngresoAlSistema] ([idLog], [idUsuario], [fechaIngreso]) VALUES (CAST(1 AS Numeric(18, 0)), 1, CAST(N'2023-07-26T02:16:55.650' AS DateTime))
INSERT [dbo].[LogIngresoAlSistema] ([idLog], [idUsuario], [fechaIngreso]) VALUES (CAST(2 AS Numeric(18, 0)), 1, CAST(N'2023-07-26T02:18:28.123' AS DateTime))
INSERT [dbo].[LogIngresoAlSistema] ([idLog], [idUsuario], [fechaIngreso]) VALUES (CAST(3 AS Numeric(18, 0)), 1, CAST(N'2023-07-27T13:34:17.417' AS DateTime))
SET IDENTITY_INSERT [dbo].[LogIngresoAlSistema] OFF
GO

-- %% [markdown]
-- # [dbo].[LogServicios]

-- %%
SET IDENTITY_INSERT [dbo].[LogServicios] ON 
INSERT [dbo].[LogServicios] ([IdLogServicios], [Servicio], [Peticion], [Respuesta], [FechaRegistro]) VALUES (CAST(14 AS Numeric(18, 0)), N'GET https://mavenai.azurewebsites.net/', N' ', NULL, CAST(N'2023-08-19T19:18:24.010' AS DateTime))
INSERT [dbo].[LogServicios] ([IdLogServicios], [Servicio], [Peticion], [Respuesta], [FechaRegistro]) VALUES (CAST(13 AS Numeric(18, 0)), N'GET https://mavenai.azurewebsites.net/', N' ', NULL, CAST(N'2023-08-19T19:18:24.010' AS DateTime))
INSERT [dbo].[LogServicios] ([IdLogServicios], [Servicio], [Peticion], [Respuesta], [FechaRegistro]) VALUES (CAST(12 AS Numeric(18, 0)), N'GET https://localhost:44334/administracion/ChatGPTFineTunesAdministracion/GetAllFineTunes', N' ', N'[]', CAST(N'2023-08-19T18:02:21.983' AS DateTime))
INSERT [dbo].[LogServicios] ([IdLogServicios], [Servicio], [Peticion], [Respuesta], [FechaRegistro]) VALUES (CAST(11 AS Numeric(18, 0)), N'GET https://localhost:44334/administracion/ChatGPTFineTunesAdministracion/GetAllFineTunes', N' ', N'[]', CAST(N'2023-08-19T18:01:17.800' AS DateTime))
INSERT [dbo].[LogServicios] ([IdLogServicios], [Servicio], [Peticion], [Respuesta], [FechaRegistro]) VALUES (CAST(10 AS Numeric(18, 0)), N'GET https://localhost:44334/api/ChatGPTFineTunesApi/GetApiFineTune', N' ', N'{
  "object": "list",
  "data": [
    {
      "object": "fine-tune",
      "id": "ft-PGjXV2DDhki6JTGV3l8eOVZq",
      "hyperparams": {
        "n_epochs": 4,
        "batch_size": null,
        "prompt_loss_weight": 0.01,
        "learning_rate_multiplier": null
      },
      "organization_id": "org-fV2FseOeS0sgCwTHwKaq0LaD",
      "model": "ada",
      "training_files": [
        {
          "object": "file",
          "id": "file-sF5ds3qdLdH9C3K8G2ZyLmtO",
          "purpose": "fine-tune",
          "filename": "archivoEntrenamiento_25_07_2023.jsonl",
          "bytes": 13392,
          "created_at": 1690303838,
          "status": "processed",
          "status_details": null
        }
      ],
      "validation_files": [],
      "result_files": [],
      "created_at": 1690303838,
      "updated_at": 1690304431,
      "status": "cancelled",
      "fine_tuned_model": null
    },
    {
      "object": "fine-tune",
      "id": "ft-zoVgc3OA3I1JNVmizJa5DgMq",
      "hyperparams": {
        "n_epochs": 4,
        "batch_size": null,
        "prompt_loss_weight": 0.01,
        "learning_rate_multiplier": null
      },
      "organization_id": "org-fV2FseOeS0sgCwTHwKaq0LaD",
      "model": "ada",
      "training_files": [
        {
          "object": "file",
          "id": "file-HEv3geJpGKs26mbjPRXn63cO",
          "purpose": "fine-tune",
          "filename": "archivoEntrenamiento_25_07_2023.jsonl",
          "bytes": 13392,
          "created_at": 1690304659,
          "status": "processed",
          "status_details": null
        }
      ],
      "validation_files": [],
      "result_files": [],
      "created_at": 1690304660,
      "updated_at": 1690304681,
      "status": "cancelled",
      "fine_tuned_model": null
    },
    {
      "object": "fine-tune",
      "id": "ft-UPa7ycD3KnpvhcyF2Wmo1niV",
      "hyperparams": {
        "n_epochs": 4,
        "batch_size": 1,
        "prompt_loss_weight": 0.01,
        "learning_rate_multiplier": 0.1
      },
      "organization_id": "org-fV2FseOeS0sgCwTHwKaq0LaD",
      "model": "ada",
      "training_files": [
        {
          "object": "file",
          "id": "file-hLH4B2N3aXY2t03EFKhvzy36",
          "purpose": "fine-tune",
          "filename": "archivoEntrenamiento_25_07_2023.jsonl",
          "bytes": 13392,
          "created_at": 1690304756,
          "status": "processed",
          "status_details": null
        }
      ],
      "validation_files": [],
      "result_files": [
        {
          "object": "file",
          "id": "file-51AZQdiu640MbPvm2mocQsUy",
          "purpose": "fine-tune-results",
          "filename": "compiled_results.csv",
          "bytes": 25807,
          "created_at": 1690318935,
          "status": "processed",
          "status_details": null
        }
      ],
      "created_at": 1690304757,
      "updated_at": 1690318936,
      "status": "succeeded",
      "fine_tuned_model": "ada:ft-maven-2023-07-25-21-02-15"
    },
    {
      "object": "fine-tune",
      "id": "ft-BeqCgUXrxOjMl6P5sLKMBacH",
      "hyperparams": {
        "n_epochs": 4,
        "batch_size": 1,
        "prompt_loss_weight": 0.01,
        "learning_rate_multiplier": 0.1
      },
      "organization_id": "org-fV2FseOeS0sgCwTHwKaq0LaD",
      "model": "ada",
      "training_files": [
        {
          "object": "file",
          "id": "file-E8XDiffTElTaFzlENO2Fo4VJ",
          "purpose": "fine-tune",
          "filename": "archivoEntrenamiento_25_07_2023.jsonl",
          "bytes": 265,
          "created_at": 1690314711,
          "status": "processed",
          "status_details": null
        }
      ],
      "validation_files": [],
      "result_files": [
        {
          "object": "file",
          "id": "file-zL1yinyoeWmxuvGITaWB8My1",
          "purpose": "fine-tune-results",
          "filename": "compiled_results.csv",
          "bytes": 553,
          "created_at": 1690323903,
          "status": "processed",
          "status_details": null
        }
      ],
      "created_at": 1690314711,
      "updated_at": 1690323904,
      "status": "succeeded",
      "fine_tuned_model": "ada:ft-maven-2023-07-25-22-25-03"
    }
  ],
  "next_starting_after": null
}
', CAST(N'2023-08-19T18:00:26.300' AS DateTime))
INSERT [dbo].[LogServicios] ([IdLogServicios], [Servicio], [Peticion], [Respuesta], [FechaRegistro]) VALUES (CAST(9 AS Numeric(18, 0)), N'GET https://mavenai.azurewebsites.net/api/ChatGPT/UseChatGPT', N'?query=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..yKu4N7e643X6p5yRKne-is_ubNdDfDjvN1CGeJbZc88%22%2C%20%20%20%22expiration%22%3A%20%222023-08-06T23%3A34%3A17.5443372Z ', NULL, CAST(N'2023-07-27T13:34:52.293' AS DateTime))
INSERT [dbo].[LogServicios] ([IdLogServicios], [Servicio], [Peticion], [Respuesta], [FechaRegistro]) VALUES (CAST(8 AS Numeric(18, 0)), N'GET https://mavenai.azurewebsites.net/api/ChatGPT/UseChatGPT', N'?query=Hola ', NULL, CAST(N'2023-07-27T13:34:40.273' AS DateTime))
INSERT [dbo].[LogServicios] ([IdLogServicios], [Servicio], [Peticion], [Respuesta], [FechaRegistro]) VALUES (CAST(7 AS Numeric(18, 0)), N'POST https://mavenai.azurewebsites.net/api/Cuentas/Login', N' {
  "usuario": "f2losada",
  "password": "123456.LM"
}', N'{"token":"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..yKu4N7e643X6p5yRKne-is_ubNdDfDjvN1CGeJbZc88","expiration":"2023-08-06T23:34:17.5443372Z"}', CAST(N'2023-07-27T13:34:18.087' AS DateTime))
INSERT [dbo].[LogServicios] ([IdLogServicios], [Servicio], [Peticion], [Respuesta], [FechaRegistro]) VALUES (CAST(6 AS Numeric(18, 0)), N'GET https://mavenai.azurewebsites.net/api/ChatGPTFineTunesApi/GetApiFineTune', N' ', N'{
  "object": "list",
  "data": [
    {
      "object": "fine-tune",
      "id": "ft-PGjXV2DDhki6JTGV3l8eOVZq",
      "hyperparams": {
        "n_epochs": 4,
        "batch_size": null,
        "prompt_loss_weight": 0.01,
        "learning_rate_multiplier": null
      },
      "organization_id": "org-fV2FseOeS0sgCwTHwKaq0LaD",
      "model": "ada",
      "training_files": [
        {
          "object": "file",
          "id": "file-sF5ds3qdLdH9C3K8G2ZyLmtO",
          "purpose": "fine-tune",
          "filename": "archivoEntrenamiento_25_07_2023.jsonl",
          "bytes": 13392,
          "created_at": 1690303838,
          "status": "processed",
          "status_details": null
        }
      ],
      "validation_files": [],
      "result_files": [],
      "created_at": 1690303838,
      "updated_at": 1690304431,
      "status": "cancelled",
      "fine_tuned_model": null
    },
    {
      "object": "fine-tune",
      "id": "ft-zoVgc3OA3I1JNVmizJa5DgMq",
      "hyperparams": {
        "n_epochs": 4,
        "batch_size": null,
        "prompt_loss_weight": 0.01,
        "learning_rate_multiplier": null
      },
      "organization_id": "org-fV2FseOeS0sgCwTHwKaq0LaD",
      "model": "ada",
      "training_files": [
        {
          "object": "file",
          "id": "file-HEv3geJpGKs26mbjPRXn63cO",
          "purpose": "fine-tune",
          "filename": "archivoEntrenamiento_25_07_2023.jsonl",
          "bytes": 13392,
          "created_at": 1690304659,
          "status": "processed",
          "status_details": null
        }
      ],
      "validation_files": [],
      "result_files": [],
      "created_at": 1690304660,
      "updated_at": 1690304681,
      "status": "cancelled",
      "fine_tuned_model": null
    },
    {
      "object": "fine-tune",
      "id": "ft-UPa7ycD3KnpvhcyF2Wmo1niV",
      "hyperparams": {
        "n_epochs": 4,
        "batch_size": 1,
        "prompt_loss_weight": 0.01,
        "learning_rate_multiplier": 0.1
      },
      "organization_id": "org-fV2FseOeS0sgCwTHwKaq0LaD",
      "model": "ada",
      "training_files": [
        {
          "object": "file",
          "id": "file-hLH4B2N3aXY2t03EFKhvzy36",
          "purpose": "fine-tune",
          "filename": "archivoEntrenamiento_25_07_2023.jsonl",
          "bytes": 13392,
          "created_at": 1690304756,
          "status": "processed",
          "status_details": null
        }
      ],
      "validation_files": [],
      "result_files": [
        {
          "object": "file",
          "id": "file-51AZQdiu640MbPvm2mocQsUy",
          "purpose": "fine-tune-results",
          "filename": "compiled_results.csv",
          "bytes": 25807,
          "created_at": 1690318935,
          "status": "processed",
          "status_details": null
        }
      ],
      "created_at": 1690304757,
      "updated_at": 1690318936,
      "status": "succeeded",
      "fine_tuned_model": "ada:ft-maven-2023-07-25-21-02-15"
    },
    {
      "object": "fine-tune",
      "id": "ft-BeqCgUXrxOjMl6P5sLKMBacH",
      "hyperparams": {
        "n_epochs": 4,
        "batch_size": 1,
        "prompt_loss_weight": 0.01,
        "learning_rate_multiplier": 0.1
      },
      "organization_id": "org-fV2FseOeS0sgCwTHwKaq0LaD",
      "model": "ada",
      "training_files": [
        {
          "object": "file",
          "id": "file-E8XDiffTElTaFzlENO2Fo4VJ",
          "purpose": "fine-tune",
          "filename": "archivoEntrenamiento_25_07_2023.jsonl",
          "bytes": 265,
          "created_at": 1690314711,
          "status": "processed",
          "status_details": null
        }
      ],
      "validation_files": [],
      "result_files": [
        {
          "object": "file",
          "id": "file-zL1yinyoeWmxuvGITaWB8My1",
          "purpose": "fine-tune-results",
          "filename": "compiled_results.csv",
          "bytes": 553,
          "created_at": 1690323903,
          "status": "processed",
          "status_details": null
        }
      ],
      "created_at": 1690314711,
      "updated_at": 1690323904,
      "status": "succeeded",
      "fine_tuned_model": "ada:ft-maven-2023-07-25-22-25-03"
    }
  ]
}
', CAST(N'2023-07-26T02:23:14.247' AS DateTime))
INSERT [dbo].[LogServicios] ([IdLogServicios], [Servicio], [Peticion], [Respuesta], [FechaRegistro]) VALUES (CAST(5 AS Numeric(18, 0)), N'POST https://mavenai.azurewebsites.net/api/Cuentas/Login', N' {
  "usuario": "f2losada",
  "password": "123456.LM"
}', N'{"token":"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..Ndtdveryr7A2rOR6D1P69TKUM00-4Yi584wDJrPnVPE","expiration":"2023-08-05T12:18:28.2080861Z"}', CAST(N'2023-07-26T02:18:28.580' AS DateTime))
INSERT [dbo].[LogServicios] ([IdLogServicios], [Servicio], [Peticion], [Respuesta], [FechaRegistro]) VALUES (CAST(4 AS Numeric(18, 0)), N'GET https://mavenai.azurewebsites.net/', N' ', NULL, CAST(N'2023-07-26T02:17:28.093' AS DateTime))
INSERT [dbo].[LogServicios] ([IdLogServicios], [Servicio], [Peticion], [Respuesta], [FechaRegistro]) VALUES (CAST(3 AS Numeric(18, 0)), N'GET https://mavenai.azurewebsites.net/', N' ', NULL, CAST(N'2023-07-26T02:17:28.093' AS DateTime))
INSERT [dbo].[LogServicios] ([IdLogServicios], [Servicio], [Peticion], [Respuesta], [FechaRegistro]) VALUES (CAST(2 AS Numeric(18, 0)), N'POST https://localhost:44334/api/Cuentas/Login', N' {
  "usuario": "f2losada",
  "password": "123456.LM"
}', N'{"token":"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..mfgl2-zy8Vlh8t6-xdtDltBXZFAJt3EnAO6TqyUoME8","expiration":"2023-08-05T12:16:55.7754647Z"}', CAST(N'2023-07-26T02:16:56.170' AS DateTime))
INSERT [dbo].[LogServicios] ([IdLogServicios], [Servicio], [Peticion], [Respuesta], [FechaRegistro]) VALUES (CAST(1 AS Numeric(18, 0)), N'POST https://localhost:44334/api/Cuentas/Login', N' {
  "usuario": "f2losada",
  "password": "123456.LM"
}', N'{"contentType":null,"serializerSettings":null,"statusCode":null,"value":{"statusCode":400,"message":"Error:  Se genero un error al consultar el usuario: Invalid object name ''LogIngresoAlSistema''."}}', CAST(N'2023-07-26T02:16:03.380' AS DateTime))
SET IDENTITY_INSERT [dbo].[LogServicios] OFF
GO

-- %% [markdown]
-- # [dbo].[LogTrainings]

-- %%
SET IDENTITY_INSERT [dbo].[LogTrainings] ON 
INSERT [dbo].[LogTrainings] ([Id], [TrainingId], [TrainingDate]) VALUES (1, N'ft-BeqCgUXrxOjMl6P5sLKMBacH', CAST(N'2023-07-25T14:51:51.837' AS DateTime))
SET IDENTITY_INSERT [dbo].[LogTrainings] OFF
GO

-- %% [markdown]
-- # [dbo].[Perfil]

-- %%
SET IDENTITY_INSERT [dbo].[Perfil] ON 
INSERT [dbo].[Perfil] ([idPerfil], [idEmpresa], [perfil], [descripcion], [idEstado], [fecha], [idUsuarioCreacion], [fechaCreacion], [idUsuarioModificacion], [fechaModificacion]) VALUES (1, 1, N'Administrador Desarrollo', N'Usuario sel area de desarrollo', 1, CAST(N'2022-05-26T00:00:00' AS SmallDateTime), 1, CAST(N'2022-05-26T00:00:00.000' AS DateTime), 1, CAST(N'2022-05-26T00:00:00.000' AS DateTime))
SET IDENTITY_INSERT [dbo].[Perfil] OFF
GO

-- %% [markdown]
-- # [dbo].[UsuarioSistema]

-- %%
SET IDENTITY_INSERT [dbo].[UsuarioSistema] ON 
INSERT [dbo].[UsuarioSistema] ([idUsuario], [numeroIdentificacion], [nombreApellido], [telefonos], [email], [idCiudad], [usuario], [pwd], [idEstado], [bloqueado], [fechaCreacion], [idEmpresa], [idArea], [token], [fechaExpiracionToken], [idUsuarioCreacion], [idusuarioModifica], [fechaModificacion], [fechaultimoIngreso], [fechaCambioClave], [idPerfil]) VALUES (1, N'12278588', N'Faiber Losada', N'3113425908', N'ITDevelopment@logytechmobile.com', 150, N'F2losada', N'2d8d5fab025b18380c335c6f6f2f42b28cfb67502f38f1455f4c68d41b200d5e', 1, 0, CAST(N'2022-04-28T18:52:11.050' AS DateTime), 1, 1, NULL, NULL, 1, 1, CAST(N'2022-11-04T16:23:13.017' AS DateTime), CAST(N'2023-07-27T13:34:17.447' AS DateTime), CAST(N'2023-07-25T16:22:54.243' AS DateTime), 1)
SET IDENTITY_INSERT [dbo].[UsuarioSistema] OFF
GO

-- %% [markdown]
-- # [UK_UsuarioSistema_Usuario]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UK_UsuarioSistema_Usuario]    Script Date: 19/08/2023 4:24:16 p. m. ******/
ALTER TABLE [dbo].[UsuarioSistema] ADD  CONSTRAINT [UK_UsuarioSistema_Usuario] UNIQUE NONCLUSTERED 
(
	[usuario] DESC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF_Area_fechaCreacion]

-- %%
ALTER TABLE [dbo].[Area] ADD  CONSTRAINT [DF_Area_fechaCreacion]  DEFAULT (getdate()) FOR [fechaCreacion]
GO

-- %% [markdown]
-- # [DF_Area_fechaModificacion]

-- %%
ALTER TABLE [dbo].[Area] ADD  CONSTRAINT [DF_Area_fechaModificacion]  DEFAULT (getdate()) FOR [fechaModificacion]
GO

-- %% [markdown]
-- # [DF__Area__idEstado__01BE3717]

-- %%
ALTER TABLE [dbo].[Area] ADD  CONSTRAINT [DF__Area__idEstado__01BE3717]  DEFAULT ((0)) FOR [idEstado]
GO

-- %% [markdown]
-- # [DF_Ciudades_estado]

-- %%
ALTER TABLE [dbo].[Ciudades] ADD  CONSTRAINT [DF_Ciudades_estado]  DEFAULT ((1)) FOR [estado]
GO

-- %% [markdown]
-- # [DF_ConfigValues_idEstado]

-- %%
ALTER TABLE [dbo].[ConfigValues] ADD  CONSTRAINT [DF_ConfigValues_idEstado]  DEFAULT ((1)) FOR [idEstado]
GO

-- %% [markdown]
-- # [DF_Conversation_DateCreation]

-- %%
ALTER TABLE [dbo].[Conversation] ADD  CONSTRAINT [DF_Conversation_DateCreation]  DEFAULT (getdate()) FOR [DateCreation]
GO

-- %% [markdown]
-- # [DF_Conversation_DateModification]

-- %%
ALTER TABLE [dbo].[Conversation] ADD  CONSTRAINT [DF_Conversation_DateModification]  DEFAULT (getdate()) FOR [DateModification]
GO

-- %% [markdown]
-- # [DF_Customer_DateCreation]

-- %%
ALTER TABLE [dbo].[Customer] ADD  CONSTRAINT [DF_Customer_DateCreation]  DEFAULT (getdate()) FOR [DateCreation]
GO

-- %% [markdown]
-- # [DF_Customer_DateModification]

-- %%
ALTER TABLE [dbo].[Customer] ADD  CONSTRAINT [DF_Customer_DateModification]  DEFAULT (getdate()) FOR [DateModification]
GO

-- %% [markdown]
-- # [DF_Empresa_Empresa]

-- %%
ALTER TABLE [dbo].[Empresa] ADD  CONSTRAINT [DF_Empresa_Empresa]  DEFAULT (getdate()) FOR [nombre]
GO

-- %% [markdown]
-- # [DF_Empresa_fechaCreacion]

-- %%
ALTER TABLE [dbo].[Empresa] ADD  CONSTRAINT [DF_Empresa_fechaCreacion]  DEFAULT (getdate()) FOR [fechaCreacion]
GO

-- %% [markdown]
-- # [DF_Empresa_fechaModificacion]

-- %%
ALTER TABLE [dbo].[Empresa] ADD  CONSTRAINT [DF_Empresa_fechaModificacion]  DEFAULT (getdate()) FOR [fechaModificacion]
GO

-- %% [markdown]
-- # [DF_HistorialPwdUsuario_fechaModificacion]

-- %%
ALTER TABLE [dbo].[HistorialPwdUsuario] ADD  CONSTRAINT [DF_HistorialPwdUsuario_fechaModificacion]  DEFAULT (getdate()) FOR [fechaModificacion]
GO

-- %% [markdown]
-- # [DF_HistorialPwdUsuario_IngresoPrimeraVez]

-- %%
ALTER TABLE [dbo].[HistorialPwdUsuario] ADD  CONSTRAINT [DF_HistorialPwdUsuario_IngresoPrimeraVez]  DEFAULT ((1)) FOR [IngresoPrimeraVez]
GO

-- %% [markdown]
-- # [DF_LogIngresoAlSistema_fechaIngreso]

-- %%
ALTER TABLE [dbo].[LogIngresoAlSistema] ADD  CONSTRAINT [DF_LogIngresoAlSistema_fechaIngreso]  DEFAULT (getdate()) FOR [fechaIngreso]
GO

-- %% [markdown]
-- # [DF__LogIntegr__fecha__Registo_Default]

-- %%
ALTER TABLE [dbo].[LogServicios] ADD  CONSTRAINT [DF__LogIntegr__fecha__Registo_Default]  DEFAULT (getdate()) FOR [FechaRegistro]
GO

-- %% [markdown]
-- # [DF_perfiles_estado]

-- %%
ALTER TABLE [dbo].[Perfil] ADD  CONSTRAINT [DF_perfiles_estado]  DEFAULT ((1)) FOR [idEstado]
GO

-- %% [markdown]
-- # [DF_perfiles_fecha]

-- %%
ALTER TABLE [dbo].[Perfil] ADD  CONSTRAINT [DF_perfiles_fecha]  DEFAULT (getdate()) FOR [fecha]
GO

-- %% [markdown]
-- # [DF_TrainingInformation_FechaRegistro]

-- %%
ALTER TABLE [dbo].[TrainingInformation] ADD  CONSTRAINT [DF_TrainingInformation_FechaRegistro]  DEFAULT (getdate()) FOR [FechaRegistro]
GO

-- %% [markdown]
-- # [DF_UsuarioSistema_idEstado]

-- %%
ALTER TABLE [dbo].[UsuarioSistema] ADD  CONSTRAINT [DF_UsuarioSistema_idEstado]  DEFAULT ((1)) FOR [idEstado]
GO

-- %% [markdown]
-- # [DF_UsuarioSistema_bloqueo]

-- %%
ALTER TABLE [dbo].[UsuarioSistema] ADD  CONSTRAINT [DF_UsuarioSistema_bloqueo]  DEFAULT ((0)) FOR [bloqueado]
GO

-- %% [markdown]
-- # [DF_UsuarioSistema_fechaCreacion]

-- %%
ALTER TABLE [dbo].[UsuarioSistema] ADD  CONSTRAINT [DF_UsuarioSistema_fechaCreacion]  DEFAULT (getdate()) FOR [fechaCreacion]
GO

-- %% [markdown]
-- # [DF_UsuarioSistema_fechaUltimaModificacion]

-- %%
ALTER TABLE [dbo].[UsuarioSistema] ADD  CONSTRAINT [DF_UsuarioSistema_fechaUltimaModificacion]  DEFAULT (getdate()) FOR [fechaModificacion]
GO

-- %% [markdown]
-- # [DF_UsuarioSistema_fechaIngreso]

-- %%
ALTER TABLE [dbo].[UsuarioSistema] ADD  CONSTRAINT [DF_UsuarioSistema_fechaIngreso]  DEFAULT (getdate()) FOR [fechaultimoIngreso]
GO

-- %% [markdown]
-- # [DF_UsuarioSistema_fechaCambioClave]

-- %%
ALTER TABLE [dbo].[UsuarioSistema] ADD  CONSTRAINT [DF_UsuarioSistema_fechaCambioClave]  DEFAULT (getdate()) FOR [fechaCambioClave]
GO

-- %% [markdown]
-- # [FK_Area_Empresa]

-- %%
ALTER TABLE [dbo].[Area]  WITH CHECK ADD  CONSTRAINT [FK_Area_Empresa] FOREIGN KEY([idEmpresa])
REFERENCES [dbo].[Empresa] ([idEmpresa])
GO
ALTER TABLE [dbo].[Area] CHECK CONSTRAINT [FK_Area_Empresa]
GO

-- %% [markdown]
-- # [FK_Conversation_Customer]

-- %%
ALTER TABLE [dbo].[Conversation]  WITH CHECK ADD  CONSTRAINT [FK_Conversation_Customer] FOREIGN KEY([idCustomer])
REFERENCES [dbo].[Customer] ([IdCustomer])
GO
ALTER TABLE [dbo].[Conversation] CHECK CONSTRAINT [FK_Conversation_Customer]
GO

-- %% [markdown]
-- # [FK_Conversation_UsuarioSistema]

-- %%
ALTER TABLE [dbo].[Conversation]  WITH CHECK ADD  CONSTRAINT [FK_Conversation_UsuarioSistema] FOREIGN KEY([idUserCreation])
REFERENCES [dbo].[UsuarioSistema] ([idUsuario])
GO
ALTER TABLE [dbo].[Conversation] CHECK CONSTRAINT [FK_Conversation_UsuarioSistema]
GO

-- %% [markdown]
-- # [FK_Conversation_UsuarioSistema1]

-- %%
ALTER TABLE [dbo].[Conversation]  WITH CHECK ADD  CONSTRAINT [FK_Conversation_UsuarioSistema1] FOREIGN KEY([idUserModification])
REFERENCES [dbo].[UsuarioSistema] ([idUsuario])
GO
ALTER TABLE [dbo].[Conversation] CHECK CONSTRAINT [FK_Conversation_UsuarioSistema1]
GO

-- %% [markdown]
-- # [FK_Customer_UsuarioSistema]

-- %%
ALTER TABLE [dbo].[Customer]  WITH CHECK ADD  CONSTRAINT [FK_Customer_UsuarioSistema] FOREIGN KEY([IdUserCreation])
REFERENCES [dbo].[UsuarioSistema] ([idUsuario])
GO
ALTER TABLE [dbo].[Customer] CHECK CONSTRAINT [FK_Customer_UsuarioSistema]
GO

-- %% [markdown]
-- # [FK_Customer_UsuarioSistema1]

-- %%
ALTER TABLE [dbo].[Customer]  WITH CHECK ADD  CONSTRAINT [FK_Customer_UsuarioSistema1] FOREIGN KEY([IdUserModification])
REFERENCES [dbo].[UsuarioSistema] ([idUsuario])
GO
ALTER TABLE [dbo].[Customer] CHECK CONSTRAINT [FK_Customer_UsuarioSistema1]
GO

-- %% [markdown]
-- # [FK_HistorialPwdUsuario_UsuarioSistema]

-- %%
ALTER TABLE [dbo].[HistorialPwdUsuario]  WITH CHECK ADD  CONSTRAINT [FK_HistorialPwdUsuario_UsuarioSistema] FOREIGN KEY([idUsuario])
REFERENCES [dbo].[UsuarioSistema] ([idUsuario])
GO
ALTER TABLE [dbo].[HistorialPwdUsuario] CHECK CONSTRAINT [FK_HistorialPwdUsuario_UsuarioSistema]
GO

-- %% [markdown]
-- # [FK_LogIngresoAlSistema_UsuarioSistema]

-- %%
ALTER TABLE [dbo].[LogIngresoAlSistema]  WITH CHECK ADD  CONSTRAINT [FK_LogIngresoAlSistema_UsuarioSistema] FOREIGN KEY([idUsuario])
REFERENCES [dbo].[UsuarioSistema] ([idUsuario])
GO
ALTER TABLE [dbo].[LogIngresoAlSistema] CHECK CONSTRAINT [FK_LogIngresoAlSistema_UsuarioSistema]
GO

-- %% [markdown]
-- # [FK_Perfil_Empresa]

-- %%
ALTER TABLE [dbo].[Perfil]  WITH CHECK ADD  CONSTRAINT [FK_Perfil_Empresa] FOREIGN KEY([idEmpresa])
REFERENCES [dbo].[Empresa] ([idEmpresa])
GO
ALTER TABLE [dbo].[Perfil] CHECK CONSTRAINT [FK_Perfil_Empresa]
GO

-- %% [markdown]
-- # [FK_UsuarioSistema_Area]

-- %%
ALTER TABLE [dbo].[UsuarioSistema]  WITH CHECK ADD  CONSTRAINT [FK_UsuarioSistema_Area] FOREIGN KEY([idArea])
REFERENCES [dbo].[Area] ([idArea])
GO
ALTER TABLE [dbo].[UsuarioSistema] CHECK CONSTRAINT [FK_UsuarioSistema_Area]
GO

-- %% [markdown]
-- # [FK_UsuarioSistema_Empresa]

-- %%
ALTER TABLE [dbo].[UsuarioSistema]  WITH CHECK ADD  CONSTRAINT [FK_UsuarioSistema_Empresa] FOREIGN KEY([idEmpresa])
REFERENCES [dbo].[Empresa] ([idEmpresa])
GO
ALTER TABLE [dbo].[UsuarioSistema] CHECK CONSTRAINT [FK_UsuarioSistema_Empresa]
GO

-- %% [markdown]
-- # [FK_UsuarioSistema_Perfil]

-- %%
ALTER TABLE [dbo].[UsuarioSistema]  WITH CHECK ADD  CONSTRAINT [FK_UsuarioSistema_Perfil] FOREIGN KEY([idPerfil])
REFERENCES [dbo].[Perfil] ([idPerfil])
GO
ALTER TABLE [dbo].[UsuarioSistema] CHECK CONSTRAINT [FK_UsuarioSistema_Perfil]
GO

-- %% [markdown]
-- # [dbo].[ConsultaPerfilesPorUsuario]

-- %%
/****** Object:  StoredProcedure [dbo].[ConsultaPerfilesPorUsuario]    Script Date: 19/08/2023 4:24:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO






-- =============================================
-- Author:		Faiber Losada Zuñiga
-- Create date: 06-02-2023
-- Description:	Procedimiento de consulta para perfiles por usuario
-- =============================================
CREATE PROCEDURE [dbo].[ConsultaPerfilesPorUsuario]  
	@IdUser INT
AS
BEGIN
	SET NOCOUNT ON;
	SELECT 
		up.idPerfil,
		p.Perfil		
		FROM dbo.UsuarioSistema AS up WITH(NOLOCK)
		INNER JOIN Perfil p ON p.idPerfil = up.idPerfil WHERE up.idUsuario = @IdUser
			
END
GO
ALTER AUTHORIZATION ON [dbo].[ConsultaPerfilesPorUsuario] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[ConsultarUnUsuarioSistema]

-- %%
/****** Object:  StoredProcedure [dbo].[ConsultarUnUsuarioSistema]    Script Date: 19/08/2023 4:24:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO





-- =============================================
-- Author:		Faiber Losada Zuñiga
-- Create date: 06-02-2023
-- Description:	Procedimiento que permite validar el acceso de un usuario
-- =============================================
CREATE PROCEDURE [dbo].[ConsultarUnUsuarioSistema]  
	@IdUser INT
AS
BEGIN
	SET NOCOUNT ON;
		SELECT * FROM  dbo.UsuarioSistema AS us WITH(NOLOCK) where idUsuario=@IdUser
			
END
GO
ALTER AUTHORIZATION ON [dbo].[ConsultarUnUsuarioSistema] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[ConsultarUnUsuarioSistemaPorToken]

-- %%
/****** Object:  StoredProcedure [dbo].[ConsultarUnUsuarioSistemaPorToken]    Script Date: 19/08/2023 4:24:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO












-- =============================================
-- Author:		Faiber Losada Zuñiga
-- Create date: 06-02-2023
-- Description:	Procedimiento que permite validar el acceso de un usuario
-- =============================================
CREATE PROCEDURE [dbo].[ConsultarUnUsuarioSistemaPorToken]  
	@Token VARCHAR(450)
AS
BEGIN
	SET NOCOUNT ON;


		SELECT * FROM  dbo.UsuarioSistema AS us WITH(NOLOCK) where us.token=@Token
			
END
GO
ALTER AUTHORIZATION ON [dbo].[ConsultarUnUsuarioSistemaPorToken] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[ConsultarUsuarioSistema]

-- %%
/****** Object:  StoredProcedure [dbo].[ConsultarUsuarioSistema]    Script Date: 19/08/2023 4:24:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



-- =============================================
-- Author:		Faiber Losada Zuñiga
-- Create date: 29-04-2022
-- Description:	Procedimiento que permite validar el acceso de un usuario
-- =============================================
CREATE PROCEDURE [dbo].[ConsultarUsuarioSistema]  

	@IdEstado INT = NULL
AS
BEGIN
	SET NOCOUNT ON;
		SELECT * FROM  dbo.UsuarioSistema WITH(NOLOCK) WHERE (@IdEstado IS NULL OR IdEstado = @IdEstado)
			
END
GO
ALTER AUTHORIZATION ON [dbo].[ConsultarUsuarioSistema] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[ConsultarUsuarioSistemaPerfil]

-- %%
/****** Object:  StoredProcedure [dbo].[ConsultarUsuarioSistemaPerfil]    Script Date: 19/08/2023 4:24:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


-- =============================================
-- Author:		Faiber Losada Zuñiga
-- Create date: 29-04-2022
-- Description:	Procedimiento que permite validar el acceso de un usuario
-- =============================================
CREATE PROCEDURE [dbo].[ConsultarUsuarioSistemaPerfil]  @idUsuario INT

AS
BEGIN
	SET NOCOUNT ON;
		SELECT us.idUsuario,
               us.numeroIdentificacion,
               us.nombreApellido,
               us.telefonos,
               us.email,
               us.idCiudad,
               us.usuario,
               us.pwd,
			   us.idEstado,
			   us.idPerfil,
			   p.perfil,
               us.bloqueado,
               us.fechaCreacion,
               us.idUsuarioCreacion,
               us.idusuarioModifica,
               us.fechaModificacion,
               us.fechaultimoIngreso,
               us.fechaCambioClave,
               us.token,
               us.fechaExpiracionToken 
			   FROM  dbo.UsuarioSistema AS us WITH(NOLOCK)
			   INNER JOIN dbo.Perfil AS p WITH(NOLOCK) ON us.idPerfil = p.idPerfil
			   WHERE US.idUsuario = @idUsuario
			
END
GO
ALTER AUTHORIZATION ON [dbo].[ConsultarUsuarioSistemaPerfil] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[DeleteFineTuneId]

-- %%
/****** Object:  StoredProcedure [dbo].[DeleteFineTuneId]    Script Date: 19/08/2023 4:24:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


-- =============================================
-- Author:		Faiber Losada Zuñiga
-- Create date: 24/07/2023
-- Description:	Delete one record from training information table by id
-- =============================================
CREATE PROCEDURE [dbo].[DeleteFineTuneId]
	-- Add the parameters for the stored procedure here
	@Id INT,
	@Mensaje VARCHAR(500) OUTPUT

AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    -- Insert statements for procedure here
	IF NOT EXISTS (SELECT Id FROM TrainingInformation WITH(NOLOCK) WHERE Id = @Id)
		BEGIN
			SET @Mensaje = CONCAT('Record ', @Id, ' doesn''t exist')
			RETURN '100';
		END
	ELSE
		BEGIN
			DELETE FROM TrainingInformation WHERE Id = @Id
			SET @Mensaje = CONCAT('Record ', @Id, ' has been deleted')
			RETURN '200';
		END

END
GO
ALTER AUTHORIZATION ON [dbo].[DeleteFineTuneId] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[GetAllChat]

-- %%
/****** Object:  StoredProcedure [dbo].[GetAllChat]    Script Date: 19/08/2023 4:24:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


-- =============================================
-- Author:		Faiber Losada
-- Create date: 149/08/2023
-- Description:	Gets the conversations of a client
-- =============================================
CREATE PROCEDURE [dbo].[GetAllChat]
	@idUser INT,
	@Email VARCHAR(100)
	-- Add the parameters for the stored procedure here
AS
DECLARE @idCustomer INT
BEGIN
	SELECT @idCustomer=idCustomer FROM Customer WITH(NOLOCK) WHERE Email=@Email

	SELECT idConversation, Ask,Answer,Reaction,Message  FROM [Conversation] WITH(NOLOCK) WHERE idCustomer=@idCustomer
END
GO
ALTER AUTHORIZATION ON [dbo].[GetAllChat] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[GetAllFineTunes]

-- %%
/****** Object:  StoredProcedure [dbo].[GetAllFineTunes]    Script Date: 19/08/2023 4:24:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


-- =============================================
-- Author:		Faiber Losada Zuñiga
-- Create date: 21/07/2023
-- Description:	Obtiene información de todos los FineTune
-- =============================================
CREATE PROCEDURE [dbo].[GetAllFineTunes]
	-- Add the parameters for the stored procedure here
AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    -- Insert statements for procedure here
	SELECT Id, prompt,completion  FROM TrainingInformation WITH(NOLOCK)
END
GO
ALTER AUTHORIZATION ON [dbo].[GetAllFineTunes] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[GetAllFineTunesToTraining]

-- %%
/****** Object:  StoredProcedure [dbo].[GetAllFineTunesToTraining]    Script Date: 19/08/2023 4:24:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


-- =============================================
-- Author:		Faiber Losada Zuñiga
-- Create date: 21/07/2023
-- Description:	Obtiene información de todos los FineTune
-- =============================================
CREATE PROCEDURE [dbo].[GetAllFineTunesToTraining]
	-- Add the parameters for the stored procedure here
AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    -- Insert statements for procedure here
	SELECT prompt + ' ->' prompt, ' ' + completion + ' END' completion FROM TrainingInformation WITH(NOLOCK)
END
GO
ALTER AUTHORIZATION ON [dbo].[GetAllFineTunesToTraining] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[GetFineTuneId]

-- %%
/****** Object:  StoredProcedure [dbo].[GetFineTuneId]    Script Date: 19/08/2023 4:24:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


-- =============================================
-- Author:		Faiber Losada Zuñiga
-- Create date: 21/07/2023
-- Description:	Obtiene información de un FineTune por Id
-- =============================================
CREATE PROCEDURE [dbo].[GetFineTuneId]
	-- Add the parameters for the stored procedure here
	@Id INT
AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    -- Insert statements for procedure here
	SELECT * FROM TrainingInformation WITH(NOLOCK)
	WHERE Id = @Id
END
GO
ALTER AUTHORIZATION ON [dbo].[GetFineTuneId] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[GetTrainingLog]

-- %%
/****** Object:  StoredProcedure [dbo].[GetTrainingLog]    Script Date: 19/08/2023 4:24:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


-- =============================================
-- Author:		Faiber Losada Zuñiga
-- Create date: 24/07/2023
-- Description:	Get training log
-- =============================================
CREATE PROCEDURE [dbo].[GetTrainingLog]
	-- Add the parameters for the stored procedure here
AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    -- Insert statements for procedure here
	SELECT * FROM LogTrainings WITH(NOLOCK)
END
GO
ALTER AUTHORIZATION ON [dbo].[GetTrainingLog] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[InsertAllFineTunes]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertAllFineTunes]    Script Date: 19/08/2023 4:24:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


-- =============================================
-- Author:		Faiber Losada Zuñiga
-- Create date: 21/07/2023
-- Description:	Inserta todos los FineTunes
-- =============================================
CREATE PROCEDURE [dbo].[InsertAllFineTunes]
	-- Add the parameters for the stored procedure here
	@idUsuario INT,
	@FineTunesList dbo.FineTunesList READONLY,
	@Mensaje VARCHAR(500) OUTPUT

AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;
	BEGIN TRY
		-- Insert statements for procedure here
		INSERT TrainingInformation (Prompt, Completion, IdUsuario, FechaRegistro)
		SELECT Prompt, Completion, @idUsuario, GETDATE() FROM @FineTunesList
		SET @Mensaje = 'Fine Tuenes registered '
		RETURN 200
	END TRY
	BEGIN CATCH
		SET @Mensaje =  ERROR_MESSAGE() +' LINEA'+ CONVERT(VARCHAR, ERROR_LINE())
		RETURN 100

	END CATCH
			
END
GO
ALTER AUTHORIZATION ON [dbo].[InsertAllFineTunes] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[InsertConversation]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertConversation]    Script Date: 19/08/2023 4:24:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



-- =============================================
-- Author:		Faiber Losada
-- Create date: 19/08/2023
-- Description:	Insert the conversations 
-- =============================================
CREATE PROCEDURE [dbo].[InsertConversation]
	-- Add the parameters for the stored procedure here
	@idUser INT,
	@Email VARCHAR(100),
	@Ask VARCHAR(MAX),
	@Answer  VARCHAR(MAX)
AS
DECLARE @idCustomer INT
BEGIN


	SET NOCOUNT ON;
	BEGIN TRY
		SELECT @idCustomer=idCustomer FROM Customer WITH(NOLOCK) WHERE Email=@Email
			IF (@idCustomer IS NULL) BEGIN
			 INSERT INTO Customer(Email,idUserCreation,DateCreation,idUserModification,DateModification)
				VALUES (@Email,@idUser,GETDATE(),@idUser,GETDATE())
				SET @idCustomer= @@IDENTITY
			END
		INSERT INTO [Conversation](idCustomer,Ask,Answer,idUserCreation,DateCreation,idUserModification,DateModification) 
		VALUES (@idCustomer,@Ask,@Answer,@idUser,GETDATE(),@idUser,GETDATE())
	END TRY
	BEGIN CATCH
		


	END CATCH
			
END
GO
ALTER AUTHORIZATION ON [dbo].[InsertConversation] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[InsertCustomern]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertCustomern]    Script Date: 19/08/2023 4:24:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


-- =============================================
-- Author:		Faiber Losada
-- Create date: 19/08/2023
-- Description:	Insert the Customern 
-- =============================================
CREATE PROCEDURE [dbo].[InsertCustomern]
	-- Add the parameters for the stored procedure here
	@Name VARCHAR(150),
	@PhotoProfile  VARCHAR(MAX),
	@Email VARCHAR(100),
	@CountryLocation VARCHAR(200),
	@UserId VARCHAR(50),
	@idUser INT	
AS
DECLARE @idCustomer INT
BEGIN


	SET NOCOUNT ON;
	BEGIN TRY
			 SELECT @idCustomer=idCustomer FROM Customer WITH(NOLOCK) WHERE Email=@Email
			IF (@idCustomer IS NULL) BEGIN
				INSERT INTO Customer([Name],PhotoProfile,Email,CountryLocation,UserId,idUserCreation,DateCreation,idUserModification,DateModification)
				VALUES (@Name,@PhotoProfile,@Email,@CountryLocation,@UserId,@idUser,GETDATE(),@idUser,GETDATE())
			END ELSE BEGIN
				UPDATE cm
				SET 
				[Name]=@Name,
				PhotoProfile=@PhotoProfile,
				CountryLocation=@CountryLocation,
				UserId=@UserId,
				idUserModification=@idUser,
				DateModification=GETDATE()
				FROM Customer cm WITH(NOLOCK) WHERE idCustomer=idCustomer
			END
			
	END TRY
	BEGIN CATCH
		


	END CATCH
			
END
GO
ALTER AUTHORIZATION ON [dbo].[InsertCustomern] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[InsertReaction]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertReaction]    Script Date: 19/08/2023 4:24:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


-- =============================================
-- Author:		Faiber Losada
-- Create date: 19/08/2023
-- Description:	Insert the reaction conversations 
-- =============================================
CREATE PROCEDURE [dbo].[InsertReaction]
	-- Add the parameters for the stored procedure here
	@idUser INT,
	@IdConversation INT,
	@Reaction BIT,
	@Message VARCHAR(200),
	@Mensaje VARCHAR(500) OUTPUT
AS
BEGIN


	SET NOCOUNT ON;
	BEGIN TRY
		UPDATE [Conversation]
		SET
			[Reaction]=@Reaction,
			[Message]=@Message,
			idUserModification=@idUser,
			DateModification=GETDATE()
			WHERE idConversation=@IdConversation
			SET @Mensaje = 'the reaction was registered correctly'
			RETURN 200
	END TRY
	BEGIN CATCH
		SET @Mensaje = 'An error was generated when registering the reaction '+ ERROR_MESSAGE() +' LINEA'+ CONVERT(VARCHAR, ERROR_LINE())
		RETURN 100
		
	END CATCH
			
END
GO
ALTER AUTHORIZATION ON [dbo].[InsertReaction] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[ObtenerInfoConfigValues]

-- %%
/****** Object:  StoredProcedure [dbo].[ObtenerInfoConfigValues]    Script Date: 19/08/2023 4:24:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




-- =============================================  
-- Author:  Faiber Losada Zuñiga
-- Create date: 29 septiembre 2022
-- Description: Obtiene el listado de configvalues filtrado por el nombre del nombre
-- =============================================  
CREATE PROCEDURE [dbo].[ObtenerInfoConfigValues] @nombre VARCHAR(50)=NULL
AS  
BEGIN  
	SET NOCOUNT ON;
	
	SELECT cv.idConfig, cv.nombre, cv.valor FROM ConfigValues cv WITH(NOLOCK) WHERE cv.nombre = @nombre
	
END
GO
ALTER AUTHORIZATION ON [dbo].[ObtenerInfoConfigValues] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[RegisterLogTrainings]

-- %%
/****** Object:  StoredProcedure [dbo].[RegisterLogTrainings]    Script Date: 19/08/2023 4:24:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


-- =============================================
-- Author:		Faiber Losada Zuñiga
-- Create date: 24/07/2023
-- Description:	Register log for each training
-- =============================================
CREATE PROCEDURE [dbo].[RegisterLogTrainings]
	-- Add the parameters for the stored procedure here
	@TrainingId VARCHAR(250)
AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    -- Insert statements for procedure here
	DELETE FROM LogTrainings
	INSERT LogTrainings (TrainingId, TrainingDate)
	VALUES (@TrainingId, GETDATE())
END
GO
ALTER AUTHORIZATION ON [dbo].[RegisterLogTrainings] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[RegistrarLogServicios]

-- %%
/****** Object:  StoredProcedure [dbo].[RegistrarLogServicios]    Script Date: 19/08/2023 4:24:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



-- =============================================
-- Author:		Faiber Losada Zuñiga
-- Create date: 09-06-2023
-- Description: Registra los errores de las transacciones API .
-- =============================================
CREATE PROCEDURE [dbo].[RegistrarLogServicios]
			@Servicio VARCHAR(1000),
			@Peticion VARCHAR(MAX) = NULL,
			@Respuesta VARCHAR(MAX) = NULL
AS
BEGIN
	SET NOCOUNT ON;
	
	
	INSERT INTO LogServicios 
		(Servicio,Peticion,Respuesta,FechaRegistro)
	VALUES 
		(@Servicio,@Peticion, @Respuesta ,GETDATE());
	
END
GO
ALTER AUTHORIZATION ON [dbo].[RegistrarLogServicios] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[ValidarTokenUsuario]

-- %%
/****** Object:  StoredProcedure [dbo].[ValidarTokenUsuario]    Script Date: 19/08/2023 4:24:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




-- =============================================
-- Author:		Faiber Losada Zuñiga
-- Create date: 29 de septiembre de 2022
-- Description:	Valida si un token es válido
-- =============================================

CREATE PROCEDURE [dbo].[ValidarTokenUsuario]
	@token VARCHAR(100)
	
AS
DECLARE @result INT;
BEGIN
	IF EXISTS(SELECT * FROM dbo.UsuarioSistema WITH(NOLOCK) WHERE token = @token AND fechaExpiracionToken > GETDATE())
	BEGIN
	   SET @result  = 1
	   
	END
	ELSE
	BEGIN
	   SET @result  = 0  
	END
	
END
SELECT idUsuario, usuario, pwd ,@result AS result  FROM dbo.UsuarioSistema WITH(NOLOCK) WHERE token = @token
GO
ALTER AUTHORIZATION ON [dbo].[ValidarTokenUsuario] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[ValidarUsuarioSistema]

-- %%
/****** Object:  StoredProcedure [dbo].[ValidarUsuarioSistema]    Script Date: 19/08/2023 4:24:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO






-- =============================================
-- Author:		Faiber Losada Zuñiga
-- Create date: 29-04-2022
-- Description:	Procedimiento que permite validar el acceso de un usuario
-- =============================================
CREATE PROCEDURE [dbo].[ValidarUsuarioSistema]  
	@usuario VARCHAR(50),
	@pwd VARCHAR(100)
AS
BEGIN
	SET NOCOUNT ON;
	INSERT INTO LogIngresoAlSistema 
		      (idUsuario,fechaIngreso)
    SELECT   us.idUsuario,GETDATE()
		FROM UsuarioSistema us WITH(NOLOCK) 		
		WHERE us.idEstado=1 AND us.bloqueado=0
			AND us.usuario=@usuario
			AND us.pwd=@pwd
		SELECT 
			us.idUsuario,us.email
		FROM UsuarioSistema us WITH(NOLOCK) 		
		WHERE us.idEstado=1 AND us.bloqueado=0
			AND us.usuario=@usuario
			AND us.pwd=@pwd
			
END
GO
ALTER AUTHORIZATION ON [dbo].[ValidarUsuarioSistema] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [dbo].[ValidarUsuarioSistemaToken]

-- %%
/****** Object:  StoredProcedure [dbo].[ValidarUsuarioSistemaToken]    Script Date: 19/08/2023 4:24:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




-- =============================================
-- Author:		Faiber Losada Zuñiga
-- Create date: 29-04-2022
-- Description:	Procedimiento que permite validar el acceso de un usuario
-- =============================================
CREATE PROCEDURE [dbo].[ValidarUsuarioSistemaToken]  
	@usuario VARCHAR(50),
	@pwd VARCHAR(100)
AS
BEGIN
	SET NOCOUNT ON;
	INSERT INTO LogIngresoAlSistema 
		      (idUsuario,fechaIngreso)
    SELECT   us.idUsuario,GETDATE()
		FROM UsuarioSistema us WITH(NOLOCK) 		
		WHERE us.idEstado=1 AND us.bloqueado=0
			AND us.usuario=@usuario
			AND us.pwd=@pwd;
	UPDATE dbo.UsuarioSistema SET fechaultimoIngreso=GETDATE()
	WHERE usuario = @usuario;

		SELECT TOP 1
			us.idUsuario,us.nombreApellido,us.email,us.idPerfil,p.perfil,us.idEmpresa,em.nombre AS NombreEmpresa, us.fechaCambioClave
		FROM UsuarioSistema us WITH(NOLOCK) 
			INNER JOIN Empresa em WITH(NOLOCK) ON us.idEmpresa=em.idEmpresa
			INNER JOIN dbo.Perfil AS p ON us.idPerfil = p.idPerfil
		WHERE us.idEstado=1 AND us.bloqueado=0
			AND us.usuario=@usuario
			AND us.pwd=@pwd
			
END
GO
ALTER AUTHORIZATION ON [dbo].[ValidarUsuarioSistemaToken] TO  SCHEMA OWNER 
GO

-- %% [markdown]
-- # [_WA_Sys_00000002_797309D9]

-- %%
/****** Object:  Statistic [_WA_Sys_00000002_797309D9]    Script Date: 19/08/2023 4:24:16 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000002_797309D9] ON [dbo].[Area]([idEmpresa]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000003_797309D9]

-- %%
/****** Object:  Statistic [_WA_Sys_00000003_797309D9]    Script Date: 19/08/2023 4:24:16 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000003_797309D9] ON [dbo].[Area]([nombre]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000004_797309D9]

-- %%
/****** Object:  Statistic [_WA_Sys_00000004_797309D9]    Script Date: 19/08/2023 4:24:16 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000004_797309D9] ON [dbo].[Area]([descripcion]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000005_797309D9]

-- %%
/****** Object:  Statistic [_WA_Sys_00000005_797309D9]    Script Date: 19/08/2023 4:24:16 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000005_797309D9] ON [dbo].[Area]([reprecentante]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000006_797309D9]

-- %%
/****** Object:  Statistic [_WA_Sys_00000006_797309D9]    Script Date: 19/08/2023 4:24:16 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000006_797309D9] ON [dbo].[Area]([idUsuarioCreacion]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000007_797309D9]

-- %%
/****** Object:  Statistic [_WA_Sys_00000007_797309D9]    Script Date: 19/08/2023 4:24:16 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000007_797309D9] ON [dbo].[Area]([fechaCreacion]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000008_797309D9]

-- %%
/****** Object:  Statistic [_WA_Sys_00000008_797309D9]    Script Date: 19/08/2023 4:24:16 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000008_797309D9] ON [dbo].[Area]([idUsuarioModificacion]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000009_797309D9]

-- %%
/****** Object:  Statistic [_WA_Sys_00000009_797309D9]    Script Date: 19/08/2023 4:24:16 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000009_797309D9] ON [dbo].[Area]([fechaModificacion]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_0000000A_797309D9]

-- %%
/****** Object:  Statistic [_WA_Sys_0000000A_797309D9]    Script Date: 19/08/2023 4:24:17 p. m. ******/
CREATE STATISTICS [_WA_Sys_0000000A_797309D9] ON [dbo].[Area]([idEstado]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [PK_Area]

-- %%
/****** Object:  Statistic [PK_Area]    Script Date: 19/08/2023 4:24:17 p. m. ******/
UPDATE STATISTICS [dbo].[Area]([PK_Area]) WITH STATS_STREAM = 0x01000000010000000000000000000000ED0358EE0000000040000000000000000000000000000000380300003800000004000A00000000000000000000000000,ROWCOUNT = 1,PAGECOUNT = 1,AUTO_DROP = OFF
GO

-- %% [markdown]
-- # [PK_ciudades]

-- %%
/****** Object:  Statistic [PK_ciudades]    Script Date: 19/08/2023 4:24:17 p. m. ******/
UPDATE STATISTICS [dbo].[Ciudades]([PK_ciudades]) WITH STATS_STREAM = 0x01000000010000000000000000000000ED0358EE0000000040000000000000000000000000000000380300003800000004000A00000000000000000000000000,ROWCOUNT = 0,PAGECOUNT = 0,AUTO_DROP = OFF
GO

-- %% [markdown]
-- # [_WA_Sys_00000002_7D439ABD]

-- %%
/****** Object:  Statistic [_WA_Sys_00000002_7D439ABD]    Script Date: 19/08/2023 4:24:17 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000002_7D439ABD] ON [dbo].[ConfigValues]([nombre]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000003_7D439ABD]

-- %%
/****** Object:  Statistic [_WA_Sys_00000003_7D439ABD]    Script Date: 19/08/2023 4:24:17 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000003_7D439ABD] ON [dbo].[ConfigValues]([valor]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000004_7D439ABD]

-- %%
/****** Object:  Statistic [_WA_Sys_00000004_7D439ABD]    Script Date: 19/08/2023 4:24:17 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000004_7D439ABD] ON [dbo].[ConfigValues]([idEstado]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [PK_ConfigValues]

-- %%
/****** Object:  Statistic [PK_ConfigValues]    Script Date: 19/08/2023 4:24:17 p. m. ******/
UPDATE STATISTICS [dbo].[ConfigValues]([PK_ConfigValues]) WITH STATS_STREAM = 0x0100000001000000000000000000000053989B1900000000400000000000000000000000000000006C0300006C00000009001200000000000000000000000000,ROWCOUNT = 1,PAGECOUNT = 1,AUTO_DROP = OFF
GO

-- %% [markdown]
-- # [PK_Conversation]

-- %%
/****** Object:  Statistic [PK_Conversation]    Script Date: 19/08/2023 4:24:17 p. m. ******/
UPDATE STATISTICS [dbo].[Conversation]([PK_Conversation]) WITH STATS_STREAM = 0x01000000010000000000000000000000ED0358EE0000000040000000000000000000000000000000380300003800000004000A00000000000000000000000000,ROWCOUNT = 0,PAGECOUNT = 0,AUTO_DROP = OFF
GO

-- %% [markdown]
-- # [PK_Customer]

-- %%
/****** Object:  Statistic [PK_Customer]    Script Date: 19/08/2023 4:24:17 p. m. ******/
UPDATE STATISTICS [dbo].[Customer]([PK_Customer]) WITH STATS_STREAM = 0x01000000010000000000000000000000ED0358EE0000000040000000000000000000000000000000380300003800000004000A00000000000000000000000000,ROWCOUNT = 0,PAGECOUNT = 0,AUTO_DROP = OFF
GO

-- %% [markdown]
-- # [_WA_Sys_00000002_7F2BE32F]

-- %%
/****** Object:  Statistic [_WA_Sys_00000002_7F2BE32F]    Script Date: 19/08/2023 4:24:17 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000002_7F2BE32F] ON [dbo].[Empresa]([nit]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000003_7F2BE32F]

-- %%
/****** Object:  Statistic [_WA_Sys_00000003_7F2BE32F]    Script Date: 19/08/2023 4:24:17 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000003_7F2BE32F] ON [dbo].[Empresa]([nombre]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000004_7F2BE32F]

-- %%
/****** Object:  Statistic [_WA_Sys_00000004_7F2BE32F]    Script Date: 19/08/2023 4:24:18 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000004_7F2BE32F] ON [dbo].[Empresa]([direccion]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000005_7F2BE32F]

-- %%
/****** Object:  Statistic [_WA_Sys_00000005_7F2BE32F]    Script Date: 19/08/2023 4:24:18 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000005_7F2BE32F] ON [dbo].[Empresa]([telefono]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000006_7F2BE32F]

-- %%
/****** Object:  Statistic [_WA_Sys_00000006_7F2BE32F]    Script Date: 19/08/2023 4:24:18 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000006_7F2BE32F] ON [dbo].[Empresa]([reprecentante]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000007_7F2BE32F]

-- %%
/****** Object:  Statistic [_WA_Sys_00000007_7F2BE32F]    Script Date: 19/08/2023 4:24:18 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000007_7F2BE32F] ON [dbo].[Empresa]([idUsuarioCreacion]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000008_7F2BE32F]

-- %%
/****** Object:  Statistic [_WA_Sys_00000008_7F2BE32F]    Script Date: 19/08/2023 4:24:18 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000008_7F2BE32F] ON [dbo].[Empresa]([fechaCreacion]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000009_7F2BE32F]

-- %%
/****** Object:  Statistic [_WA_Sys_00000009_7F2BE32F]    Script Date: 19/08/2023 4:24:18 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000009_7F2BE32F] ON [dbo].[Empresa]([idUsuarioModificacion]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_0000000A_7F2BE32F]

-- %%
/****** Object:  Statistic [_WA_Sys_0000000A_7F2BE32F]    Script Date: 19/08/2023 4:24:18 p. m. ******/
CREATE STATISTICS [_WA_Sys_0000000A_7F2BE32F] ON [dbo].[Empresa]([fechaModificacion]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [PK_Empresa]

-- %%
/****** Object:  Statistic [PK_Empresa]    Script Date: 19/08/2023 4:24:18 p. m. ******/
UPDATE STATISTICS [dbo].[Empresa]([PK_Empresa]) WITH STATS_STREAM = ...,ROWCOUNT = 1,PAGECOUNT = 1,AUTO_DROP = OFF
GO

-- %% [markdown]
-- # [PK_HistorialPwdUsuario]

-- %%
/****** Object:  Statistic [PK_HistorialPwdUsuario]    Script Date: 19/08/2023 4:24:18 p. m. ******/
UPDATE STATISTICS [dbo].[HistorialPwdUsuario]([PK_HistorialPwdUsuario]) WITH STATS_STREAM = 0x01000000010000000000000000000000ED0358EE0000000040000000000000000000000000000000380300003800000004000A00000000000000000000000000,ROWCOUNT = 0,PAGECOUNT = 0,AUTO_DROP = OFF
GO

-- %% [markdown]
-- # [PK_LogIngresoAlSistema]

-- %%
/****** Object:  Statistic [PK_LogIngresoAlSistema]    Script Date: 19/08/2023 4:24:18 p. m. ******/
UPDATE STATISTICS [dbo].[LogIngresoAlSistema]([PK_LogIngresoAlSistema]) WITH STATS_STREAM = 0x0100000001000000000000000000000053989B1900000000400000000000000000000000000000006C0300006C00000009001200000000000000000000000000,ROWCOUNT = 3,PAGECOUNT = 1,AUTO_DROP = OFF
GO

-- %% [markdown]
-- # [PK_LogIntegracionClaro]

-- %%
/****** Object:  Statistic [PK_LogIntegracionClaro]    Script Date: 19/08/2023 4:24:18 p. m. ******/
UPDATE STATISTICS [dbo].[LogServicios]([PK_LogIntegracionClaro]) WITH STATS_STREAM = 0x0100000001000000000000000000000053989B1900000000400000000000000000000000000000006C0300006C00000009001200000000000000000000000000,ROWCOUNT = 14,PAGECOUNT = 2,AUTO_DROP = OFF
GO

-- %% [markdown]
-- # [PK_LogTrainingInformation]

-- %%
/****** Object:  Statistic [PK_LogTrainingInformation]    Script Date: 19/08/2023 4:24:18 p. m. ******/
UPDATE STATISTICS [dbo].[LogTrainingInformation]([PK_LogTrainingInformation]) WITH STATS_STREAM = 0x01000000010000000000000000000000ED0358EE0000000040000000000000000000000000000000380300003800000004000A00000000000000000000000000,ROWCOUNT = 0,PAGECOUNT = 0,AUTO_DROP = OFF
GO

-- %% [markdown]
-- # [_WA_Sys_00000002_06CD04F7]

-- %%
/****** Object:  Statistic [_WA_Sys_00000002_06CD04F7]    Script Date: 19/08/2023 4:24:19 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000002_06CD04F7] ON [dbo].[LogTrainings]([TrainingId]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000003_06CD04F7]

-- %%
/****** Object:  Statistic [_WA_Sys_00000003_06CD04F7]    Script Date: 19/08/2023 4:24:19 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000003_06CD04F7] ON [dbo].[LogTrainings]([TrainingDate]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000002_07C12930]

-- %%
/****** Object:  Statistic [_WA_Sys_00000002_07C12930]    Script Date: 19/08/2023 4:24:19 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000002_07C12930] ON [dbo].[Perfil]([idEmpresa]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000003_07C12930]

-- %%
/****** Object:  Statistic [_WA_Sys_00000003_07C12930]    Script Date: 19/08/2023 4:24:19 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000003_07C12930] ON [dbo].[Perfil]([perfil]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000004_07C12930]

-- %%
/****** Object:  Statistic [_WA_Sys_00000004_07C12930]    Script Date: 19/08/2023 4:24:19 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000004_07C12930] ON [dbo].[Perfil]([descripcion]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000005_07C12930]

-- %%
/****** Object:  Statistic [_WA_Sys_00000005_07C12930]    Script Date: 19/08/2023 4:24:19 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000005_07C12930] ON [dbo].[Perfil]([idEstado]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000006_07C12930]

-- %%
/****** Object:  Statistic [_WA_Sys_00000006_07C12930]    Script Date: 19/08/2023 4:24:19 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000006_07C12930] ON [dbo].[Perfil]([fecha]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000007_07C12930]

-- %%
/****** Object:  Statistic [_WA_Sys_00000007_07C12930]    Script Date: 19/08/2023 4:24:19 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000007_07C12930] ON [dbo].[Perfil]([idUsuarioCreacion]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000008_07C12930]

-- %%
/****** Object:  Statistic [_WA_Sys_00000008_07C12930]    Script Date: 19/08/2023 4:24:19 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000008_07C12930] ON [dbo].[Perfil]([fechaCreacion]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000009_07C12930]

-- %%
/****** Object:  Statistic [_WA_Sys_00000009_07C12930]    Script Date: 19/08/2023 4:24:19 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000009_07C12930] ON [dbo].[Perfil]([idUsuarioModificacion]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_0000000A_07C12930]

-- %%
/****** Object:  Statistic [_WA_Sys_0000000A_07C12930]    Script Date: 19/08/2023 4:24:19 p. m. ******/
CREATE STATISTICS [_WA_Sys_0000000A_07C12930] ON [dbo].[Perfil]([fechaModificacion]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [PK_perfiles]

-- %%
/****** Object:  Statistic [PK_perfiles]    Script Date: 19/08/2023 4:24:19 p. m. ******/
UPDATE STATISTICS [dbo].[Perfil]([PK_perfiles]) WITH STATS_STREAM = ...,ROWCOUNT = 1,PAGECOUNT = 1,AUTO_DROP = OFF
GO

-- %% [markdown]
-- # [PK_TrainingInformation]

-- %%
/****** Object:  Statistic [PK_TrainingInformation]    Script Date: 19/08/2023 4:24:20 p. m. ******/
UPDATE STATISTICS [dbo].[TrainingInformation]([PK_TrainingInformation]) WITH STATS_STREAM = 0x01000000010000000000000000000000ED0358EE0000000040000000000000000000000000000000380300003800000004000A00000000000000000000000000,ROWCOUNT = 0,PAGECOUNT = 0,AUTO_DROP = OFF
GO

-- %% [markdown]
-- # [_WA_Sys_00000002_0C85DE4D]

-- %%
/****** Object:  Statistic [_WA_Sys_00000002_0C85DE4D]    Script Date: 19/08/2023 4:24:20 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000002_0C85DE4D] ON [dbo].[UsuarioSistema]([numeroIdentificacion]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000003_0C85DE4D]

-- %%
/****** Object:  Statistic [_WA_Sys_00000003_0C85DE4D]    Script Date: 19/08/2023 4:24:20 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000003_0C85DE4D] ON [dbo].[UsuarioSistema]([nombreApellido]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000004_0C85DE4D]

-- %%
/****** Object:  Statistic [_WA_Sys_00000004_0C85DE4D]    Script Date: 19/08/2023 4:24:20 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000004_0C85DE4D] ON [dbo].[UsuarioSistema]([telefonos]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000005_0C85DE4D]

-- %%
/****** Object:  Statistic [_WA_Sys_00000005_0C85DE4D]    Script Date: 19/08/2023 4:24:20 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000005_0C85DE4D] ON [dbo].[UsuarioSistema]([email]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000006_0C85DE4D]

-- %%
/****** Object:  Statistic [_WA_Sys_00000006_0C85DE4D]    Script Date: 19/08/2023 4:24:20 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000006_0C85DE4D] ON [dbo].[UsuarioSistema]([idCiudad]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000008_0C85DE4D]

-- %%
/****** Object:  Statistic [_WA_Sys_00000008_0C85DE4D]    Script Date: 19/08/2023 4:24:20 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000008_0C85DE4D] ON [dbo].[UsuarioSistema]([pwd]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000009_0C85DE4D]

-- %%
/****** Object:  Statistic [_WA_Sys_00000009_0C85DE4D]    Script Date: 19/08/2023 4:24:20 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000009_0C85DE4D] ON [dbo].[UsuarioSistema]([idEstado]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_0000000A_0C85DE4D]

-- %%
/****** Object:  Statistic [_WA_Sys_0000000A_0C85DE4D]    Script Date: 19/08/2023 4:24:20 p. m. ******/
CREATE STATISTICS [_WA_Sys_0000000A_0C85DE4D] ON [dbo].[UsuarioSistema]([bloqueado]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_0000000B_0C85DE4D]

-- %%
/****** Object:  Statistic [_WA_Sys_0000000B_0C85DE4D]    Script Date: 19/08/2023 4:24:20 p. m. ******/
CREATE STATISTICS [_WA_Sys_0000000B_0C85DE4D] ON [dbo].[UsuarioSistema]([fechaCreacion]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_0000000C_0C85DE4D]

-- %%
/****** Object:  Statistic [_WA_Sys_0000000C_0C85DE4D]    Script Date: 19/08/2023 4:24:20 p. m. ******/
CREATE STATISTICS [_WA_Sys_0000000C_0C85DE4D] ON [dbo].[UsuarioSistema]([idEmpresa]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_0000000D_0C85DE4D]

-- %%
/****** Object:  Statistic [_WA_Sys_0000000D_0C85DE4D]    Script Date: 19/08/2023 4:24:20 p. m. ******/
CREATE STATISTICS [_WA_Sys_0000000D_0C85DE4D] ON [dbo].[UsuarioSistema]([idArea]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_0000000E_0C85DE4D]

-- %%
/****** Object:  Statistic [_WA_Sys_0000000E_0C85DE4D]    Script Date: 19/08/2023 4:24:21 p. m. ******/
CREATE STATISTICS [_WA_Sys_0000000E_0C85DE4D] ON [dbo].[UsuarioSistema]([token]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_0000000F_0C85DE4D]

-- %%
/****** Object:  Statistic [_WA_Sys_0000000F_0C85DE4D]    Script Date: 19/08/2023 4:24:21 p. m. ******/
CREATE STATISTICS [_WA_Sys_0000000F_0C85DE4D] ON [dbo].[UsuarioSistema]([fechaExpiracionToken]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000010_0C85DE4D]

-- %%
/****** Object:  Statistic [_WA_Sys_00000010_0C85DE4D]    Script Date: 19/08/2023 4:24:21 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000010_0C85DE4D] ON [dbo].[UsuarioSistema]([idUsuarioCreacion]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000011_0C85DE4D]

-- %%
/****** Object:  Statistic [_WA_Sys_00000011_0C85DE4D]    Script Date: 19/08/2023 4:24:21 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000011_0C85DE4D] ON [dbo].[UsuarioSistema]([idusuarioModifica]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000012_0C85DE4D]

-- %%
/****** Object:  Statistic [_WA_Sys_00000012_0C85DE4D]    Script Date: 19/08/2023 4:24:21 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000012_0C85DE4D] ON [dbo].[UsuarioSistema]([fechaModificacion]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000013_0C85DE4D]

-- %%
/****** Object:  Statistic [_WA_Sys_00000013_0C85DE4D]    Script Date: 19/08/2023 4:24:21 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000013_0C85DE4D] ON [dbo].[UsuarioSistema]([fechaultimoIngreso]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000014_0C85DE4D]

-- %%
/****** Object:  Statistic [_WA_Sys_00000014_0C85DE4D]    Script Date: 19/08/2023 4:24:21 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000014_0C85DE4D] ON [dbo].[UsuarioSistema]([fechaCambioClave]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [_WA_Sys_00000015_0C85DE4D]

-- %%
/****** Object:  Statistic [_WA_Sys_00000015_0C85DE4D]    Script Date: 19/08/2023 4:24:21 p. m. ******/
CREATE STATISTICS [_WA_Sys_00000015_0C85DE4D] ON [dbo].[UsuarioSistema]([idPerfil]) WITH STATS_STREAM = ...,AUTO_DROP = ON
GO

-- %% [markdown]
-- # [PK_UsuarioSistema]

-- %%
/****** Object:  Statistic [PK_UsuarioSistema]    Script Date: 19/08/2023 4:24:21 p. m. ******/
UPDATE STATISTICS [dbo].[UsuarioSistema]([PK_UsuarioSistema]) WITH STATS_STREAM = 0x01000000010000000000000000000000ED0358EE0000000040000000000000000000000000000000380300003800000004000A00000000000000000000000000,ROWCOUNT = 1,PAGECOUNT = 1,AUTO_DROP = OFF
GO

-- %% [markdown]
-- # [UK_UsuarioSistema_Usuario]

-- %%
/****** Object:  Statistic [UK_UsuarioSistema_Usuario]    Script Date: 19/08/2023 4:24:21 p. m. ******/
UPDATE STATISTICS [dbo].[UsuarioSistema]([UK_UsuarioSistema_Usuario]) WITH STATS_STREAM = ...,ROWCOUNT = 1,PAGECOUNT = 1,AUTO_DROP = OFF
GO
